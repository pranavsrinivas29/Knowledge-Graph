# %% [markdown]
# <a href="https://colab.research.google.com/github/pranavsrinivas29/Knowledge-Graph/blob/main/SPARQL_Wikidata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Querying Wikidata with mkwikidata ###
#
# [mkwikidata](https://pypi.org/project/mkwikidata/#description) is a package for running SPARQL queries on Wikidata
#
# We have to install the following packages:
#
# **mkwikidata**

# %%
# !pip install mkwikidata
# Out:
# Collecting mkwikidata
#   Downloading mkwikidata-0.14-py2.py3-none-any.whl.metadata (741 bytes)
# Requirement already satisfied: requests>=2.25.1 in /usr/local/lib/python3.10/dist-packages (from mkwikidata) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.1->mkwikidata) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.1->mkwikidata) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.1->mkwikidata) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.1->mkwikidata) (2024.7.4)
# Downloading mkwikidata-0.14-py2.py3-none-any.whl (3.0 kB)
# Installing collected packages: mkwikidata
# Successfully installed mkwikidata-0.14

# %%
import mkwikidata, pprint
import pandas as pd

# %% [markdown]
# #### **Query 1**:  Show all narrated cities of books and literary works and their geo coordination in Wikidata
#
# Following Wikidata classes/instances and properties are required:
#
# [wd:Q571](https://www.wikidata.org/wiki/Q571), [wd:Q7725634](https://www.wikidata.org/wiki/Q7725634), [wd:Q515](https://www.wikidata.org/wiki/Q515),  [wdt:P31](https://www.wikidata.org/wiki/Property:P31), [wdt:P840](https://www.wikidata.org/wiki/Property:P840), [wdt:P625](https://www.wikidata.org/wiki/Property:P625) , [wdt:P279](https://www.wikidata.org/wiki/Property:P279)

# %%
query = """
SELECT ?label ?placelabel ?coord
WHERE
{
  VALUES ?type {wd:Q571 wd:Q7725634} #book or literary work
  # ?item wdt:P31 ?type . #of type ?type
  # ?item rdfs:label ?label FILTER (lang(?label) = "en") .
  # ?item wdt:P840 ?place . #narration place ?place
  # ?place wdt:P31/wdt:P279* wd:Q515 . # place is an instance or a subclass of city
  # ?place wdt:P625 ?coord . #has coordinations ?ccord
  # ?place rdfs:label ?placelabel FILTER (lang(?placelabel) = "en") .
}
"""
query_result = mkwikidata.run_query(query, params={ })
query_result
# Out:
# {'head': {'vars': ['label', 'placelabel', 'coord']},
#  'results': {'bindings': [{'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': "All Tomorrow's Parties"},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': "The Kitchen God's Wife"},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Zodiac'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'American Gods'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-63.571388888 44.647777777)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Johnny Kellock Died Today'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Halifax'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(13.021423031 55.593188589)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'BK Framåt'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Malmö'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Man in the High Castle'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Bloodsucking Fiends'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Maltese Falcon'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-1.9025 52.48)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'What Hetty Did'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Birmingham'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Do Androids Dream of Electric Sheep?'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Now and Forever'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Our Lady of Darkness'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'On the Road'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(45.341944444 2.039166666)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Crossbones'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Mogadishu'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(45.341944444 2.039166666)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Links: A Novel'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Mogadishu'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-1.9025 52.48)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': "The Rotters' Club"},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Birmingham'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-1.9025 52.48)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': "Felicia's Journey"},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Birmingham'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-1.9025 52.48)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Living'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Birmingham'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-1.9025 52.48)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Rebels and Traitors'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Birmingham'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(14.248611111 40.835833333)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Wounded to Death'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Naples'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(14.248611111 40.835833333)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': "Naples '44"},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Naples'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(14.248611111 40.835833333)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Candelaio'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Naples'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(14.248611111 40.835833333)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Filumena Marturano'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Naples'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(14.248611111 40.835833333)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Pentamerone'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Naples'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(14.248611111 40.835833333)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Devil in Love'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Naples'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(14.248611111 40.835833333)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Trickster of Seville and the Stone Guest'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Naples'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'One Crazy Summer'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Dream of Debs'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': "City Come A-Walkin'"},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Destroying Angel'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Dance of Mirrors (chap. 13-epilogue)'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Skovene'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Rise and Fall of Khan Noonien Singh, Volume 1'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Tower Of Babel'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': "The Trail to Buddha's Mirror"},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'The Circle'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': "It's Such a Beautiful Day"},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Cupcake'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Abysmal Brute'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Story of William'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Comrades: A Story of Social Adventure in California'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'El juego de Ripper'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'If Only It Were True'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Call of Cthulhu'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'A Dirty Job'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Vampire Lestat'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Necromancer: The Secrets of the Immortal Nicholas Flamel'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Queen of the Damned'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Propeller Island'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Around the World in Eighty Days'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(5.570555555 50.639722222)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Maigret at the Gai-Moulin'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Liège'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-4.25 55.861111111)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Young Mungo'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Glasgow'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(13.361261944 38.115658055)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Silent Duchess'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Palermo'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Son of Neptune'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Address Unknown'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Daughter of Fortune'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Kingdom of Fear'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Joy Luck Club'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Little Brother'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(23.317777777 38.320833333)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Amphitryon'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Thebes'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(23.317777777 38.320833333)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Infernal Machine'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Thebes'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(72.84 21.205)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Indian Dreams'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Surat'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-3.703333333 40.416944444)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Don Carlos'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Madrid'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(11.331388888 43.318333333)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Tale of Two Lovers'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Siena'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'The Iron Heel'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Scarlet Plague'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(14.248611111 40.835833333)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Les arts et l’amitié'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Naples'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(14.248611111 40.835833333)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Brick Bolding'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Naples'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(14.248611111 40.835833333)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Elegia di Madonna Fiammetta'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Naples'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(14.248611111 40.835833333)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Il marito di Elena'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Naples'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'You Can Say You Knew Me When'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Homeland'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'McTeague'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Bloody Tears'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Joy (novel)'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': '11th Hour'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': '12th of Never (novel)'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Flower Drum Song'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'South of the Pumphouse'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(14.248611111 40.835833333)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Saturday Sunday Monday'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Naples'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(13.361261944 38.115658055)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'House of Liars'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Palermo'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(13.361261944 38.115658055)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Florios of Sicily'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Palermo'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-4.25 55.861111111)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Men Should Weep'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Glasgow'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-4.25 55.861111111)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Great Cauldron'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Glasgow'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-4.25 55.861111111)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Shuggie Bain'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Glasgow'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(23.317777777 38.320833333)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Oedipus'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Thebes'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(4.808333333 43.948611111)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Sans Famille'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Avignon'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(114.158611111 22.278333333)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Around the World in Eighty Days'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Hong Kong'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-3.703333333 40.416944444)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'La Gran Vía'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Madrid'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-3.703333333 40.416944444)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'The Club Dumas'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Madrid'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-3.703333333 40.416944444)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Manuscript Found in Saragossa'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Madrid'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-3.703333333 40.416944444)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'El barberillo de Lavapiés'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Madrid'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-3.703333333 40.416944444)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Sun over Breda'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Madrid'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-3.703333333 40.416944444)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Captain Alatriste'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Madrid'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-3.703333333 40.416944444)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'El barquillero'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Madrid'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-3.703333333 40.416944444)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'The Monk'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Madrid'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(138.6 -34.9275)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Reconnoitering Voyages and Travels, with Adventures in the new colonies of South Australia'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Adelaide'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(114.158611111 22.278333333)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Painted Veil'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Hong Kong'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(138.6 -34.9275)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Journals of Expeditions of Discovery into Central Australia'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Adelaide'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(69.165833333 34.532777777)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'And the Mountains Echoed'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Kabul'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(69.165833333 34.532777777)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Shabnam'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Kabul'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(7.55 44.383333333)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Light Words between Us'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Cuneo'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(1.855555555 50.9475)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Three Musketeers'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Calais'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Sisters Brothers'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Hundred Secret Senses'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Curious Notions'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Cruise of the Dazzler'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': "The Bonesetter's Daughter"},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'You Suck: A Love Story'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'A Grave Talent'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Amazing Grace'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Dark Magic'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-3.703333333 40.416944444)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Fencing Master'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Madrid'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-3.703333333 40.416944444)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Flanders Panel'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Madrid'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-3.703333333 40.416944444)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Noche de guerra en el Museo del Prado'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Madrid'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-3.703333333 40.416944444)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Episodios Nacionales: Zaragoza'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Madrid'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-3.703333333 40.416944444)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'La verbena de la Paloma'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Madrid'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-3.703333333 40.416944444)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Bohemian Lights'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Madrid'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-3.703333333 40.416944444)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Luisa Fernanda'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Madrid'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-3.703333333 40.416944444)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Phantom Lady'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Madrid'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-3.703333333 40.416944444)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'La discreta enamorada'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Madrid'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-3.703333333 40.416944444)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Doña Francisquita'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Madrid'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Desirable Daughters'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Dragonwings'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Epiphany'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Execution of Justice'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Further Tales of the City'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Gingerbread'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'The Immigrants'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Jokerman 8'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Koolaids: The Art of War'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Landscape: Memory'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Leave It to Me'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Miracle'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'More Tales of the City'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Mr. Monk and the Blue Flu'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Mr. Monk on Patrol'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Postsingular'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Sacrament'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Signal to Noise'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Significant Others'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Sister of My Heart'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Sombrero Fallout: A Japanese Novel'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Sure of You'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Tea with the Black Dragon'},
#     'placelabel': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'San Francisco'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-122.416388888 37.7775)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
# ...
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The White Family'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Enchanted April'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Apartment 16'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Shopaholic to the Stars'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Nell Gwynn'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Playhouse Creatures'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Shadow of the Wolf'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Life and Death of Harriett Frean'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Spider'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Spies'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Straight Talking: A Novel'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Sucker Punch'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Surfeit of Lampreys'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Swing Brother Swing'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Symposium'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'System Shock'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Take a Girl Like You'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Tamburlaine Must Die'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The 12.30 from Croydon'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Acceptance World'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Adventures of Roderick Random'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'The Antipope'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'The Apes of God'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The St Zita Society'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Starlight Barking'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Story of Cirrus Flux'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Story of the Treasure Seekers'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Story of the Weasel'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The String of Pearls'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'The Stud'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'The Tain'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'The Tea Rose'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Temptation of Eileen Hughes'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'The Terrorist'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Tiger in the Smoke'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'The Trainer'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Tumbled House'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Unlimited Dream Company'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'The Vault'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': "The Vet's Daughter"},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The Wimbledon Trilogy'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'The World Is Full of Married Men'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'The Woven Path'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': "There Ain't No Justice"},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'There But For The'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'They Drive by Night'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Threepenny Novel'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Through a Glass Darkly'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Tirra Lirra by the River'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'The Big Four'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    {'coord': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral',
#      'type': 'literal',
#      'value': 'Point(-0.1275 51.507222222)'},
#     'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'High Fidelity'},
#     'placelabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}},
#    ...]}}

# %% [markdown]
# The json_normalize() function is used to convert the JSON string into a DataFrame for a more (human)readable output

# %%
results_df = pd.json_normalize(query_result['results']['bindings'])
results_df[['label.value', 'placelabel.value', 'coord.value']]
# Out:
#                             label.value placelabel.value  \
# 0                All Tomorrow's Parties    San Francisco
# 1                The Kitchen God's Wife    San Francisco
# 2                                Zodiac    San Francisco
# 3                         American Gods    San Francisco
# 4             Johnny Kellock Died Today          Halifax
# ...                                 ...              ...
# 11258                      Buddenbrooks           Lübeck
# 11259                        Martin Paz             Lima
# 11260                  The Life to Come          Colombo
# 11261  The Seven Moons of Maali Almeida          Colombo
# 11262                   Voyage à Ceilan          Colombo
#
#                              coord.value
# 0          Point(-122.416388888 37.7775)
# 1          Point(-122.416388888 37.7775)
# 2          Point(-122.416388888 37.7775)
# 3          Point(-122.416388888 37.7775)
# 4      Point(-63.571388888 44.647777777)
# ...                                  ...
# 11258   Point(10.686388888 53.869722222)
# 11259             Point(-77.0375 -12.06)
# 11260    Point(79.833333333 6.916666666)
# 11261    Point(79.833333333 6.916666666)
# 11262    Point(79.833333333 6.916666666)
#
# [11263 rows x 3 columns]

# %% [markdown]
# Let's [visualize the query](https://query.wikidata.org/#%23defaultView%3AMap%0ASELECT%20%3Flabel%20%3Fplacelabel%20%3Fcoord%0AWHERE%0A%7B%0A%20%20VALUES%20%3Ftype%20%7Bwd%3AQ571%20wd%3AQ7725634%7D%20%20%23%20book%20or%20literary%20work%0A%20%20%3Fitem%20wdt%3AP31%20%3Ftype%20.%0A%20%20%3Fitem%20rdfs%3Alabel%20%3Flabel%20FILTER%20%28lang%28%3Flabel%29%20%3D%20%22en%22%29%20.%0A%20%20%3Fitem%20wdt%3AP840%20%3Fplace%20.%20%20%23%20narration%20place%20is%20%3Fplace%0A%20%20%3Fplace%20wdt%3AP625%20%3Fcoord%20.%0A%20%20%3Fplace%20rdfs%3Alabel%20%3Fplacelabel%20FILTER%20%28lang%28%3Fplacelabel%29%20%3D%20%22en%22%29%20.%0A%7D%20%0A) result in Wikidata Query Service\!

# %% [markdown]
# #### **Query 2**: What is the most common narration country in Wikidata books and literature works? ####
#
# Following additional Wikidata classes/instances and properties are required:
#
# [wdt:P17](https://www.wikidata.org/wiki/Property:P17)

# %%
query = """
SELECT ?countrylabel (COUNT(?country) AS ?count)
WHERE
{
  VALUES ?type {wd:Q571 wd:Q7725634}  # book or literary work
  # ?item wdt:P31 ?type .
  # ?item wdt:P840 ?place . # narration place is ?place
  # ?place wdt:P17 ?country .
  # ?country rdfs:label ?countrylabel FILTER (lang(?countrylabel) = "en") .

}
  GROUP BY ?countrylabel
  ORDER BY DESC(?count)

"""
query_result = mkwikidata.run_query(query, params={ })
results_df = pd.json_normalize(query_result['results']['bindings'])
results_df[['countrylabel.value', 'count.value']]
# Out:
#            countrylabel.value count.value
# 0    United States of America        2553
# 1              United Kingdom        1605
# 2                      France        1355
# 3                       Italy         742
# 4                       Spain         616
# ..                        ...         ...
# 361   Three Kingdoms of Korea           1
# 362                    Goryeo           1
# 363      Later Three Kingdoms           1
# 364               Later Silla           1
# 365               Kievan Rus'           1
#
# [366 rows x 2 columns]

# %% [markdown]
# Let's try out the bubble chart visualization of [the query result](https://query.wikidata.org/#%23defaultView%3ABubbleChart%0ASELECT%20%3Fcountrylabel%20%28COUNT%28%3Fcountry%29%20AS%20%3Fcount%29%0AWHERE%0A%7B%0A%20%20VALUES%20%3Ftype%20%7Bwd%3AQ571%20wd%3AQ7725634%7D%20%20%23%20book%20or%20literary%20work%0A%20%20%3Fitem%20wdt%3AP31%20%3Ftype%20.%0A%20%20%3Fitem%20wdt%3AP840%20%3Fplace%20.%20%23%20narration%20place%20is%20%3Fplace%0A%20%20%3Fplace%20wdt%3AP17%20%3Fcountry%20.%0A%20%20%3Fcountry%20rdfs%3Alabel%20%3Fcountrylabel%20FILTER%20%28lang%28%3Fcountrylabel%29%20%3D%20%22en%22%29%20.%0A%0A%7D%20%0A%20%20GROUP%20BY%20%3Fcountrylabel%0A%20%20ORDER%20BY%20DESC%28%3Fcount%29%0A) in Wikidata!

# %% [markdown]
# ### Querying Wikidata with SPARQLWrapper ###
#
# Alternatively, Wikidata KG and other KGs can be queried using the [SPARQLWrapper](https://sparqlwrapper.readthedocs.io/en/latest/main.html) – a python interface for any SPARQL Endpoint.
#
# For this, we have to install and import the following packages:
#
#
# **SPARQLWrapper**

# %%
# !pip install -q sparqlwrapper    #install SPARQLwrapper
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 531.9/531.9 kB 21.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 2.6 MB/s eta 0:00:00

# %%
from SPARQLWrapper import SPARQLWrapper, JSON, XML, RDF

# %%
sparql = SPARQLWrapper("https://query.wikidata.org/sparql") #determine SPARQL endpoint
sparql.setReturnFormat(JSON) #determine the output format

# %% [markdown]
# #### **Query 3**: Being a writer is dangerous! Let's see what is the most common cause of death among writers? ####
#
# Following additional Wikidata classes/instances and properties are required:
#
# [wdt:P106](https://www.wikidata.org/wiki/Property:P106), [wdt:509](https://www.wikidata.org/wiki/Property:P509), [wd:Q36180](https://www.wikidata.org/wiki/Q36180)

# %%
# Add User-Agent header
sparql.addCustomHttpHeader('User-Agent', 'MyBot/1.0 (myemail@example.com)')
#Replace 'MyBot/1.0' and '[redacted link]' with appropriate information.

# %%
sparql.setQuery("""
SELECT ?cause ?causeLabel (COUNT(?person) AS ?count)
WHERE
{
  # ?person wdt:P106 wd:Q36180 . #occupation writer
  # ?person wdt:P509 ?cause . #?cause is a death cause
  SERVICE wikibase:label { bd:serviceParam wikibase:language "en". }
}
GROUP BY ?cause ?causeLabel
HAVING(?count > 1)
ORDER BY DESC(?count)
 """
)
results = sparql.query().convert()   # execute SPARQL query and write result to "results"
results_df = pd.json_normalize(results['results']['bindings'])
results_df[['causeLabel.value', 'count.value']]
# Out:
#                 causeLabel.value count.value
# 0                         cancer        1147
# 1          myocardial infarction        1100
# 2                   tuberculosis         580
# 3                      pneumonia         549
# 4                         stroke         443
# ..                           ...         ...
# 290      death from scuba diving           2
# 291  November 2015 Paris attacks           2
# 292                         CaVe           2
# 293                    Q78698047           2
# 294          equestrian accident           2
#
# [295 rows x 2 columns]

# %% [markdown]
# #### **Query 4**: And if we talk about writers that died before 1800? ####
#
# Following additional Wikidata classes/instances and properties are required:
#
# [wdt:P570](https://www.wikidata.org/wiki/Property:P570)

# %%
sparql.setQuery("""
SELECT ?cause ?causeLabel (COUNT(?person) AS ?count)
WHERE
{
  # ?person wdt:P106 wd:Q36180; #ocupation writer
          wdt:P509 ?cause ; #?cause is a death cause
          wdt:P570 ?date . #death date
  FILTER (?date < "1800-01-01T00:00:00Z"^^xsd:dateTime) .
  SERVICE wikibase:label { bd:serviceParam wikibase:language "en". }
}
GROUP BY ?cause ?causeLabel
HAVING(?count > 1)
ORDER BY DESC(?count)

 """
)
results = sparql.query().convert()   # execute SPARQL query and write result to "results"
results_df = pd.json_normalize(results['results']['bindings'])
results_df[['causeLabel.value', 'count.value']]
# Out:
#                             causeLabel.value count.value
# 0                               decapitation          89
# 1                                     plague          64
# 2                                    disease          55
# 3                               tuberculosis          45
# 4                           death by burning          35
# 5                                   drowning          31
# 6                                    hanging          26
# 7                                   smallpox          23
# 8                                     stroke          21
# 9                           killed in action          18
# 10                                   malaria          16
# 11                                    poison          11
# 12                            exsanguination          11
# 13                   cerebrovascular disease          10
# 14                                 pneumonia           9
# 15                       puerperal disorders           9
# 16                                horse fall           8
# 17                                     edema           7
# 18                                stab wound           7
# 19                              intoxication           6
# 20                     myocardial infarction           5
# 21                                   leprosy           5
# 22                                 poisoning           5
# 23                                 dysentery           5
# 24                                  stabbing           5
# 25                                    cancer           4
# 26  hanged, drawn, quartered and decapitated           4
# 27                                   flaying           4
# 28                        infectious disease           4
# 29                                  syphilis           3
# 30                             breast cancer           3
# 31                       cerebral hemorrhage           3
# 32                             gunshot wound           3
# 33                                  apoplexy           3
# 34                       falling from height           3
# 35                       death from laughter           3
# 36                                     fever           2
# 37                                  epidemic           2
# 38                               Black Death           2
# 39                                   measles           2
# 40                              inflammation           2
# 41                                    typhus           2
# 42                                    sepsis           2
# 43                            stomach cancer           2
# 44                            bubonic plague           2
# 45                               peritonitis           2
# 46                                   falling           2
# 47                            kidney failure           2
# 48                                     abuse           2
# 49                                starvation           2
# 50                             incarceration           2
# 51           gastrointestinal system disease           2
# 52                             assassination           2
# 53                                 execution           2
# 54                          lightning strike           2
# 55                      execution by burning           2

# %% [markdown]
# So, being a writer before 1800 could often leave you without the head. :)

# %% [markdown]
# #### **Query 5**: Now let's see how writers tend to kill their characters. ####
#
# Following additional Wikidata classes/instances and properties are required:
#
# [wdt:P674](https://www.wikidata.org/wiki/Property:P674)

# %%
sparql.setQuery("""
SELECT ?cause ?causeLabel (COUNT(?character) AS ?count)

WHERE
{
  VALUES ?type {wd:Q571 wd:Q7725634}  # book or literary work
  # ?item wdt:P31 ?type .
  # ?item wdt:P674 ?character .
  # ?character wdt:P509 ?cause .
  SERVICE wikibase:label { bd:serviceParam wikibase:language "en". }
}
GROUP BY ?cause ?causeLabel
HAVING(?count > 1)
ORDER BY DESC(?count)

 """
)
results = sparql.query().convert()   # execute SPARQL query and write result to "results"
results_df = pd.json_normalize(results['results']['bindings'])
results_df[['causeLabel.value', 'count.value']]
# Out:
#                                      causeLabel.value count.value
# 0                                       gunshot wound          56
# 1                                        decapitation          55
# 2                                    killed in action          45
# 3                                              stroke          24
# 4                                         train wreck          22
# ..                                                ...         ...
# 81                                falling from height           2
# 82                                  aviation accident           2
# 83  http://www.wikidata.org/.well-known/genid/0167...           2
# 84                                       lung disease           2
# 85                                      neurosyphilis           2
#
# [86 rows x 2 columns]

# %% [markdown]
# #### **Query 6**:  List 100 youngest authors alive from the Eastern Europe. ####

# %%
sparql.setQuery("""
SELECT DISTINCT ?personLabel ?countryLabel ?age
WHERE {
  # ?person wdt:P106 wd:Q36180 ; #occupation writer
          wdt:P27 ?country ; #country of citizenship
          wdt:P569 ?birth_date.

  BIND(year(now()) - year(?birth_date) AS ?age)
  FILTER NOT EXISTS { ?person wdt:P570 ?death } #no death date for this person exist

  # ?country wdt:P361 wd:Q27468 . #country is a part of Easter Europe

  SERVICE wikibase:label {
    bd:serviceParam wikibase:language "en". }
 }

ORDER BY (?age)
LIMIT 100

 """
)
results = sparql.query().convert()   # execute SPARQL query and write result to "results"
results_df = pd.json_normalize(results['results']['bindings'])
results_df[['personLabel.value', 'countryLabel.value', 'age.value']]
# Out:
#     personLabel.value countryLabel.value age.value
# 0       Silva Souriau            Romania       NaN
# 1         Vojta Horák     Czech Republic        16
# 2   Magdaléna Paťhová     Czech Republic        16
# 3            Coolawik             Poland        18
# 4        Tomáš Grygar     Czech Republic        18
# ..                ...                ...       ...
# 95  Nikita Laptinskiy            Belarus        31
# 96     Marie Donajová     Czech Republic        31
# 97  Kateřina Brabcová     Czech Republic        31
# 98       Ester Bezděk     Czech Republic        31
# 99      Eva Horáčková     Czech Republic        31
#
# [100 rows x 3 columns]
